# %% [markdown]
# # Starbucks Capstone Challenge
#
# ### Introduction
#
# This data set contains simulated data that mimics customer behavior on the Starbucks rewards mobile app. Once every few days, Starbucks sends out an offer to users of the mobile app. An offer can be merely an advertisement for a drink or an actual offer such as a discount or BOGO (buy one get one free). Some users might not receive any offer during certain weeks.
#
# Not all users receive the same offer, and that is the challenge to solve with this data set.
#
# Your task is to combine transaction, demographic and offer data to determine which demographic groups respond best to which offer type. This data set is a simplified version of the real Starbucks app because the underlying simulator only has one product whereas Starbucks actually sells dozens of products.
#
# Every offer has a validity period before the offer expires. As an example, a BOGO offer might be valid for only 5 days. You'll see in the data set that informational offers have a validity period even though these ads are merely providing information about a product; for example, if an informational offer has 7 days of validity, you can assume the customer is feeling the influence of the offer for 7 days after receiving the advertisement.
#
# You'll be given transactional data showing user purchases made on the app including the timestamp of purchase and the amount of money spent on a purchase. This transactional data also has a record for each offer that a user receives as well as a record for when a user actually views the offer. There are also records for when a user completes an offer.
#
# Keep in mind as well that someone using the app might make a purchase through the app without having received an offer or seen an offer.
#
# ### Example
#
# To give an example, a user could receive a discount offer buy 10 dollars get 2 off on Monday. The offer is valid for 10 days from receipt. If the customer accumulates at least 10 dollars in purchases during the validity period, the customer completes the offer.
#
# However, there are a few things to watch out for in this data set. Customers do not opt into the offers that they receive; in other words, a user can receive an offer, never actually view the offer, and still complete the offer. For example, a user might receive the "buy 10 dollars get 2 dollars off offer", but the user never opens the offer during the 10 day validity period. The customer spends 15 dollars during those ten days. There will be an offer completion record in the data set; however, the customer was not influenced by the offer because the customer never viewed the offer.
#
# ### Cleaning
#
# This makes data cleaning especially important and tricky.
#
# You'll also want to take into account that some demographic groups will make purchases even if they don't receive an offer. From a business perspective, if a customer is going to make a 10 dollar purchase without an offer anyway, you wouldn't want to send a buy 10 dollars get 2 dollars off offer. You'll want to try to assess what a certain demographic group will buy when not receiving any offers.
#
# ### Final Advice
#
# Because this is a capstone project, you are free to analyze the data any way you see fit. For example, you could build a machine learning model that predicts how much someone will spend based on demographics and offer type. Or you could build a model that predicts whether or not someone will respond to an offer. Or, you don't need to build a machine learning model at all. You could develop a set of heuristics that determine what offer you should send to each customer (i.e., 75 percent of women customers who were 35 years old responded to offer A vs 40 percent from the same demographic to offer B, so send offer A).

# %% [markdown]
# # Data Sets
#
# The data is contained in three files:
#
# * portfolio.json - containing offer ids and meta data about each offer (duration, type, etc.)
# * profile.json - demographic data for each customer
# * transcript.json - records for transactions, offers received, offers viewed, and offers completed
#
# Here is the schema and explanation of each variable in the files:
#
# **portfolio.json**
# * id (string) - offer id
# * offer_type (string) - type of offer ie BOGO, discount, informational
# * difficulty (int) - minimum required spend to complete an offer
# * reward (int) - reward given for completing an offer
# * duration (int) - time for offer to be open, in days
# * channels (list of strings)
#
# **profile.json**
# * age (int) - age of the customer
# * became_member_on (int) - date when customer created an app account
# * gender (str) - gender of the customer (note some entries contain 'O' for other rather than M or F)
# * id (str) - customer id
# * income (float) - customer's income
#
# **transcript.json**
# * event (str) - record description (ie transaction, offer received, offer viewed, etc.)
# * person (str) - customer id
# * time (int) - time in hours since start of test. The data begins at time t=0
# * value - (dict of strings) - either an offer id or transaction amount depending on the record
#
# **Note:** If you are using the workspace, you will need to go to the terminal and run the command `conda update pandas` before reading in the files. This is because the version of pandas in the workspace cannot read in the transcript.json file correctly, but the newest version of pandas can. You can access the termnal from the orange icon in the top left of this notebook.
#
# You can see how to access the terminal and how the install works using the two images below.  First you need to access the terminal:
#
# <img src="pic1.png"/>
#
# Then you will want to run the above command:
#
# <img src="pic2.png"/>
#
# Finally, when you enter back into the notebook (use the jupyter icon again), you should be able to run the below cell without any errors.

# %%
# !pip install -U seaborn
# Out:
# Requirement already up-to-date: seaborn in /opt/conda/lib/python3.6/site-packages (0.11.2)
# Requirement already satisfied, skipping upgrade: scipy>=1.0 in /opt/conda/lib/python3.6/site-packages (from seaborn) (1.2.1)
# Requirement already satisfied, skipping upgrade: matplotlib>=2.2 in /opt/conda/lib/python3.6/site-packages (from seaborn) (3.3.4)
# Requirement already satisfied, skipping upgrade: numpy>=1.15 in /opt/conda/lib/python3.6/site-packages (from seaborn) (1.19.5)
# Requirement already satisfied, skipping upgrade: pandas>=0.23 in /opt/conda/lib/python3.6/site-packages (from seaborn) (0.23.3)
# Requirement already satisfied, skipping upgrade: kiwisolver>=1.0.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib>=2.2->seaborn) (1.3.1)
# Requirement already satisfied, skipping upgrade: cycler>=0.10 in /opt/conda/lib/python3.6/site-packages/cycler-0.10.0-py3.6.egg (from matplotlib>=2.2->seaborn) (0.10.0)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.1 in /opt/conda/lib/python3.6/site-packages (from matplotlib>=2.2->seaborn) (2.6.1)
# Requirement already satisfied, skipping upgrade: pyparsing!=2.0.4,!=2.1.2,!=2.1.6,>=2.0.3 in /opt/conda/lib/python3.6/site-packages (from matplotlib>=2.2->seaborn) (2.2.0)
# Requirement already satisfied, skipping upgrade: pillow>=6.2.0 in /opt/conda/lib/python3.6/site-packages (from matplotlib>=2.2->seaborn) (8.4.0)
# Requirement already satisfied, skipping upgrade: pytz>=2011k in /opt/conda/lib/python3.6/site-packages (from pandas>=0.23->seaborn) (2017.3)
# Requirement already satisfied, skipping upgrade: six in /opt/conda/lib/python3.6/site-packages (from cycler>=0.10->matplotlib>=2.2->seaborn) (1.11.0)

# %%
import pandas as pd
import numpy as np
import math
import json
import seaborn as sns
import matplotlib.pyplot as plt

% matplotlib inline

# read in the json files
portfolio = pd.read_json('data/portfolio.json', orient='records', lines=True)
profile = pd.read_json('data/profile.json', orient='records', lines=True)
transcript = pd.read_json('data/transcript.json', orient='records', lines=True)

# %% [markdown]
# # Exploration and cleaning of Portfolio Dataframe

# %%
portfolio.head()
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
#
#                                  id     offer_type  reward
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10
# 2  3f207df678b143eea3cee63160fa8bed  informational       0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5

# %%
portfolio.shape
# Out:
# (10, 6)

# %%
len(portfolio.id.unique())
# Out:
# 10

# %%
portfolio_df = portfolio.copy()

# %%
portfolio_df['offer'] = portfolio.index + 1

# %%
portfolio_df
# Out:
#                        channels  difficulty  duration  \
# 0       [email, mobile, social]          10         7
# 1  [web, email, mobile, social]          10         5
# 2          [web, email, mobile]           0         4
# 3          [web, email, mobile]           5         7
# 4                  [web, email]          20        10
# 5  [web, email, mobile, social]           7         7
# 6  [web, email, mobile, social]          10        10
# 7       [email, mobile, social]           0         3
# 8  [web, email, mobile, social]           5         5
# 9          [web, email, mobile]          10         7
#
#                                  id     offer_type  reward  offer
# 0  ae264e3637204a6fb9bb56bc8210ddfd           bogo      10      1
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0           bogo      10      2
# 2  3f207df678b143eea3cee63160fa8bed  informational       0      3
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9           bogo       5      4
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7       discount       5      5
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2       discount       3      6
# 6  fafdcd668e3743c1bb461111dcafc2a4       discount       2      7
# 7  5a8bc65990b245e5a138643cd4eb9837  informational       0      8
# 8  f19421c1d4aa40978ebb69ca19b0e20d           bogo       5      9
# 9  2906b810c7d4411798c6938adc9daaa5       discount       2     10

# %%
def web_in_channels (channels):
    if 'web' in channels:
        return 1
    else:
        return 0

portfolio_df['web'] = portfolio_df['channels'].apply(web_in_channels)

# %%
def email_in_channels (channels):
    if 'email' in channels:
        return 1
    else:
        return 0

portfolio_df['email'] = portfolio_df['channels'].apply(email_in_channels)

# %%
def social_in_channels (channels):
    if 'social' in channels:
        return 1
    else:
        return 0

portfolio_df['social'] = portfolio_df['channels'].apply(social_in_channels)

# %%
def mobile_in_channels (channels):
    if 'mobile' in channels:
        return 1
    else:
        return 0
portfolio_df['mobile'] = portfolio_df['channels'].apply(mobile_in_channels)

# %%
portfolio_df = portfolio_df.drop('channels', axis = 1)

# %%
portfolio_df = portfolio_df[["id", "offer", "offer_type", "difficulty", "duration", "reward", "web", "email", "social", "mobile"]]

# %%
portfolio_df
# Out:
#                                  id  offer     offer_type  difficulty  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1           bogo          10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      2           bogo          10
# 2  3f207df678b143eea3cee63160fa8bed      3  informational           0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      4           bogo           5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      5       discount          20
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      6       discount           7
# 6  fafdcd668e3743c1bb461111dcafc2a4      7       discount          10
# 7  5a8bc65990b245e5a138643cd4eb9837      8  informational           0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      9           bogo           5
# 9  2906b810c7d4411798c6938adc9daaa5     10       discount          10
#
#    duration  reward  web  email  social  mobile
# 0         7      10    0      1       1       1
# 1         5      10    1      1       1       1
# 2         4       0    1      1       0       1
# 3         7       5    1      1       0       1
# 4        10       5    1      1       0       0
# 5         7       3    1      1       1       1
# 6        10       2    1      1       1       1
# 7         3       0    0      1       1       1
# 8         5       5    1      1       1       1
# 9         7       2    1      1       0       1

# %%
portfolio_df['duration'] = portfolio_df['duration'] * 24

# %%
# portfolio_df.to_csv('portfolio_df.csv', index = False)

# %%
portfolio_df
# Out:
#                                  id  offer     offer_type  difficulty  \
# 0  ae264e3637204a6fb9bb56bc8210ddfd      1           bogo          10
# 1  4d5c57ea9a6940dd891ad53e9dbe8da0      2           bogo          10
# 2  3f207df678b143eea3cee63160fa8bed      3  informational           0
# 3  9b98b8c7a33c4b65b9aebfe6a799e6d9      4           bogo           5
# 4  0b1e1539f2cc45b7b9fa7c272da2e1d7      5       discount          20
# 5  2298d6c36e964ae4a3e7e9706d1fb8c2      6       discount           7
# 6  fafdcd668e3743c1bb461111dcafc2a4      7       discount          10
# 7  5a8bc65990b245e5a138643cd4eb9837      8  informational           0
# 8  f19421c1d4aa40978ebb69ca19b0e20d      9           bogo           5
# 9  2906b810c7d4411798c6938adc9daaa5     10       discount          10
#
#    duration  reward  web  email  social  mobile
# 0       168      10    0      1       1       1
# 1       120      10    1      1       1       1
# 2        96       0    1      1       0       1
# 3       168       5    1      1       0       1
# 4       240       5    1      1       0       0
# 5       168       3    1      1       1       1
# 6       240       2    1      1       1       1
# 7        72       0    0      1       1       1
# 8       120       5    1      1       1       1
# 9       168       2    1      1       0       1

# %%
portfolio.hist()
# Out:
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_tools.py:308: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_tools.py:308: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   layout[ax.rowNum, ax.colNum] = ax.get_visible()
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_tools.py:314: MatplotlibDeprecationWarning:
# The rowNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().rowspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# /opt/conda/lib/python3.6/site-packages/pandas/plotting/_tools.py:314: MatplotlibDeprecationWarning:
# The colNum attribute was deprecated in Matplotlib 3.2 and will be removed two minor releases later. Use ax.get_subplotspec().colspan.start instead.
#   if not layout[ax.rowNum + 1, ax.colNum]:
# array([[<AxesSubplot:title={'center':'difficulty'}>,
#         <AxesSubplot:title={'center':'duration'}>],
#        [<AxesSubplot:title={'center':'reward'}>, <AxesSubplot:>]],
#       dtype=object)

# %% [markdown]
# # Exploration and Cleaning of Profile Dataframe

# %%
profile.head()
# Out:
#    age  became_member_on gender                                id    income
# 0  118          20170212   None  68be06ca386d4c31939f3a4f0e3dd783       NaN
# 1   55          20170715      F  0610b486422d4921ae7d2bf64640c50b  112000.0
# 2  118          20180712   None  38fe809add3b4fcf9315a9694bb96ff5       NaN
# 3   75          20170509      F  78afa995795e4d85b5d9ceeca43f5fef  100000.0
# 4  118          20170804   None  a03223e636434f42ac4c3df47e8bac43       NaN

# %%
profile.shape
# Out:
# (17000, 5)

# %%
len(profile.id.unique())
# Out:
# 17000

# %%
profile.isna().sum()
# Out:
# age                    0
# became_member_on       0
# gender              2175
# id                     0
# income              2175
# dtype: int64

# %%
profile_df = profile.dropna()

# %%
profile_df.isna().sum()
# Out:
# age                 0
# became_member_on    0
# gender              0
# id                  0
# income              0
# dtype: int64

# %%
sns.histplot(data = profile_df, x='age').set_title(f"Ages of Promo Recepient")
# Out:
# Text(0.5, 1.0, 'Ages of Promo Recepient')

# %%
profile_df.describe()
# Out:
#                 age  became_member_on         income
# count  14825.000000      1.482500e+04   14825.000000
# mean      54.393524      2.016689e+07   65404.991568
# std       17.383705      1.188565e+04   21598.299410
# min       18.000000      2.013073e+07   30000.000000
# 25%       42.000000      2.016052e+07   49000.000000
# 50%       55.000000      2.017080e+07   64000.000000
# 75%       66.000000      2.017123e+07   80000.000000
# max      101.000000      2.018073e+07  120000.000000

# %%
profile_df.age.unique()
# Out:
# array([ 55,  75,  68,  65,  58,  61,  26,  62,  49,  57,  40,  64,  78,
#         42,  56,  33,  46,  59,  67,  53,  22,  96,  69,  20,  45,  54,
#         39,  41,  79,  66,  29,  44,  63,  36,  76,  77,  30,  51,  27,
#         73,  74,  70,  89,  50,  90,  60,  19,  72,  52,  18,  71,  83,
#         43,  47,  32,  38,  34,  85,  48,  35,  82,  21,  24,  81,  25,
#         37,  23, 100,  28,  84,  80,  87,  86,  94,  31,  88,  95,  93,
#         91,  92,  98, 101,  97,  99])

# %%
profile_df['became_member_on'] = pd.to_datetime(profile_df['became_member_on'].astype(str), format='%Y%m%d')
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
print(min(profile_df['became_member_on']))
print(max(profile_df['became_member_on']))
# Out:
# 2013-07-29 00:00:00
# 2018-07-26 00:00:00

# %%
profile_df['membership_duration'] = round((max(profile_df['became_member_on']) - profile_df["became_member_on"]).dt.days)
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
profile_df = profile_df[["id", "age", "gender", "income", "became_member_on", "membership_duration"]]

# %%
profile_df.head()
# Out:
#                                   id  age gender    income became_member_on  \
# 1   0610b486422d4921ae7d2bf64640c50b   55      F  112000.0       2017-07-15
# 3   78afa995795e4d85b5d9ceeca43f5fef   75      F  100000.0       2017-05-09
# 5   e2127556f4f64592b11af22de27a7932   68      M   70000.0       2018-04-26
# 8   389bc3fa690240e798340f5a15918d5c   65      M   53000.0       2018-02-09
# 12  2eeac8d8feae4a8cad5a6af0499a211d   58      M   51000.0       2017-11-11
#
#     membership_duration
# 1                   376
# 3                   443
# 5                    91
# 8                   167
# 12                  257

# %%
# profile_df.to_csv('profile_df.csv', index = False)

# %%
plt.figure(figsize=(20,10))
sns.kdeplot(
    data=profile_df, 
    x="age", 
    hue="gender",
    fill=True, 
    common_norm=False, 
    palette="RdPu",
    alpha=.5, 
    linewidth=0,
)
plt.legend(labels=['Other', 'Male', 'Female'])
plt.title('Age and Gender Distribution of Starbucks Customers')
plt.show()

# %%
profile_df['gender'].value_counts().plot.pie(legend = True, 
                                             labels = ['Male', 'Female', 'Other'], 
                                             figsize=(11, 6),
                                             title = 'Gender of Starbucks Customers',
                                             autopct='%1.1f%%'
                                            )
# Out:
# <AxesSubplot:title={'center':'Gender of Starbucks Customers'}, ylabel='gender'>

# %%
plt.figure(figsize=(20,10))
sns.kdeplot(data=profile_df, 
            x="membership_duration", 
            hue="gender", 
            multiple="stack")
plt.legend(labels = ['Other', 'Male', 'Female'])
plt.title('Membership Duration of Starbucks Customers')
plt.show()

# %%
plt.figure(figsize=(20,10))
sns.kdeplot(
    data=profile_df, 
    x="income", 
    hue="gender",
    fill = True,
    palette="bright"
)
plt.legend(labels=['Other', 'Male', 'Female'])
plt.title('Income Distribution of Starbucks Customers')
plt.show()

# %% [markdown]
# # Transcript Dataframe

# %%
transcript.head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}

# %%
transcript.shape
# Out:
# (306534, 4)

# %%
transcript.event.value_counts()
# Out:
# transaction        138953
# offer received      76277
# offer viewed        57725
# offer completed     33579
# Name: event, dtype: int64

# %% [markdown]
# ## Event = Transaction

# %%
transcript[transcript.event == 'transaction'].head()
# Out:
#              event                            person  time  \
# 12654  transaction  02c083884c7d45b39cc68e1314fec56c     0
# 12657  transaction  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12659  transaction  54890f68699049c2a04d415abc25e717     0
# 12670  transaction  b2f1cd155b864803ad8334cdf13c4bd2     0
# 12671  transaction  fe97aa22dd3e48c8b143116a8403dd52     0
#
#                                 value
# 12654  {'amount': 0.8300000000000001}
# 12657               {'amount': 34.56}
# 12659               {'amount': 13.23}
# 12670               {'amount': 19.51}
# 12671               {'amount': 18.97}

# %%
offer_df = transcript.copy()

# %%
transaction_df = transcript[transcript.event == 'transaction']
transaction_df.shape
# Out:
# (138953, 4)

# %%
transaction_df.head()
# Out:
#              event                            person  time  \
# 12654  transaction  02c083884c7d45b39cc68e1314fec56c     0
# 12657  transaction  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12659  transaction  54890f68699049c2a04d415abc25e717     0
# 12670  transaction  b2f1cd155b864803ad8334cdf13c4bd2     0
# 12671  transaction  fe97aa22dd3e48c8b143116a8403dd52     0
#
#                                 value
# 12654  {'amount': 0.8300000000000001}
# 12657               {'amount': 34.56}
# 12659               {'amount': 13.23}
# 12670               {'amount': 19.51}
# 12671               {'amount': 18.97}

# %%
transaction_df['amount_spent'] = transaction_df['value'].apply(lambda x: x['amount'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
transaction_df.head()
# Out:
#              event                            person  time  \
# 12654  transaction  02c083884c7d45b39cc68e1314fec56c     0
# 12657  transaction  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12659  transaction  54890f68699049c2a04d415abc25e717     0
# 12670  transaction  b2f1cd155b864803ad8334cdf13c4bd2     0
# 12671  transaction  fe97aa22dd3e48c8b143116a8403dd52     0
#
#                                 value  amount_spent
# 12654  {'amount': 0.8300000000000001}          0.83
# 12657               {'amount': 34.56}         34.56
# 12659               {'amount': 13.23}         13.23
# 12670               {'amount': 19.51}         19.51
# 12671               {'amount': 18.97}         18.97

# %%
transaction_df = transaction_df.drop('value', axis = 1)

# %%
# transaction_df = pd.merge(
#     transaction_df,
#     profile,
#     how="inner",
#     left_on="person",
#     right_on="id",
#     copy = False,
#     sort=True,
# )

# %%
# transaction_df = transaction_df.drop("id", axis = 1)

# %%
transaction_df.head()
# Out:
#              event                            person  time  amount_spent
# 12654  transaction  02c083884c7d45b39cc68e1314fec56c     0          0.83
# 12657  transaction  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0         34.56
# 12659  transaction  54890f68699049c2a04d415abc25e717     0         13.23
# 12670  transaction  b2f1cd155b864803ad8334cdf13c4bd2     0         19.51
# 12671  transaction  fe97aa22dd3e48c8b143116a8403dd52     0         18.97

# %%
transaction_df.describe()
# Out:
#                 time   amount_spent
# count  138953.000000  138953.000000
# mean      381.584334      12.777356
# std       201.697230      30.250529
# min         0.000000       0.050000
# 25%       210.000000       2.780000
# 50%       402.000000       8.890000
# 75%       552.000000      18.070000
# max       714.000000    1062.280000

# %%
# transaction_df.to_csv('transaction.csv', index = False)

# %% [markdown]
# ## Offer Received

# %%
transcript[transcript.event == 'offer received'].head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                                               value
# 0  {'offer id': '9b98b8c7a33c4b65b9aebfe6a799e6d9'}
# 1  {'offer id': '0b1e1539f2cc45b7b9fa7c272da2e1d7'}
# 2  {'offer id': '2906b810c7d4411798c6938adc9daaa5'}
# 3  {'offer id': 'fafdcd668e3743c1bb461111dcafc2a4'}
# 4  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}

# %%
offer_received_df = transcript[transcript.event == 'offer received']
offer_received_df.shape
# Out:
# (76277, 4)

# %%
offer_received_df['offer_id'] = offer_received_df['value'].apply(lambda x: x['offer id'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
offer_received_df = offer_received_df.drop('value', axis = 1)

# %%
offer_received_df.head()
# Out:
#             event                            person  time  \
# 0  offer received  78afa995795e4d85b5d9ceeca43f5fef     0
# 1  offer received  a03223e636434f42ac4c3df47e8bac43     0
# 2  offer received  e2127556f4f64592b11af22de27a7932     0
# 3  offer received  8ec6ce2a7e7949b1bf142def7d0e0586     0
# 4  offer received  68617ca6246f4fbc85e91a2a49552598     0
#
#                            offer_id
# 0  9b98b8c7a33c4b65b9aebfe6a799e6d9
# 1  0b1e1539f2cc45b7b9fa7c272da2e1d7
# 2  2906b810c7d4411798c6938adc9daaa5
# 3  fafdcd668e3743c1bb461111dcafc2a4
# 4  4d5c57ea9a6940dd891ad53e9dbe8da0

# %%
# offer_received_df = pd.merge(
#     offer_received_df,
#     portfolio,
#     how="inner",
#     left_on="offer_id",
#     right_on="id",
#     copy = False,
#     sort=True,
# )

# %%
# offer_received_df.to_csv('offer_received.csv', index = False)

# %% [markdown]
# ## Offer Viewed

# %%
transcript[transcript.event == 'offer viewed'].head()
# Out:
#               event                            person  time  \
# 12650  offer viewed  389bc3fa690240e798340f5a15918d5c     0
# 12651  offer viewed  d1ede868e29245ea91818a903fec04c6     0
# 12652  offer viewed  102e9454054946fda62242d2e176fdce     0
# 12653  offer viewed  02c083884c7d45b39cc68e1314fec56c     0
# 12655  offer viewed  be8a5d1981a2458d90b255ddc7e0d174     0
#
#                                                   value
# 12650  {'offer id': 'f19421c1d4aa40978ebb69ca19b0e20d'}
# 12651  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}
# 12652  {'offer id': '4d5c57ea9a6940dd891ad53e9dbe8da0'}
# 12653  {'offer id': 'ae264e3637204a6fb9bb56bc8210ddfd'}
# 12655  {'offer id': '5a8bc65990b245e5a138643cd4eb9837'}

# %%
offer_viewed_df = transcript[transcript.event == 'offer viewed']
offer_viewed_df.shape
# Out:
# (57725, 4)

# %%
offer_viewed_df['offer'] = offer_viewed_df['value'].apply(lambda x: x['offer id'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
offer_viewed_df = offer_viewed_df.drop('value', axis = 1)

# %%
offer_viewed_df.head()
# Out:
#               event                            person  time  \
# 12650  offer viewed  389bc3fa690240e798340f5a15918d5c     0
# 12651  offer viewed  d1ede868e29245ea91818a903fec04c6     0
# 12652  offer viewed  102e9454054946fda62242d2e176fdce     0
# 12653  offer viewed  02c083884c7d45b39cc68e1314fec56c     0
# 12655  offer viewed  be8a5d1981a2458d90b255ddc7e0d174     0
#
#                                   offer
# 12650  f19421c1d4aa40978ebb69ca19b0e20d
# 12651  5a8bc65990b245e5a138643cd4eb9837
# 12652  4d5c57ea9a6940dd891ad53e9dbe8da0
# 12653  ae264e3637204a6fb9bb56bc8210ddfd
# 12655  5a8bc65990b245e5a138643cd4eb9837

# %%
offer_viewed_df.shape
# Out:
# (57725, 4)

# %%
# offer_viewed_df.to_csv('offer_viewed.csv', index = False)

# %% [markdown]
# ## Offer Completed

# %%
transcript[transcript.event == 'offer completed'].head()
# Out:
#                  event                            person  time  \
# 12658  offer completed  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12672  offer completed  fe97aa22dd3e48c8b143116a8403dd52     0
# 12679  offer completed  629fc02d56414d91bca360decdfa9288     0
# 12692  offer completed  676506bad68e4161b9bbaffeb039626b     0
# 12697  offer completed  8f7dd3b2afe14c078eb4f6e6fe4ba97d     0
#
#                                                    value
# 12658  {'offer_id': '2906b810c7d4411798c6938adc9daaa5...
# 12672  {'offer_id': 'fafdcd668e3743c1bb461111dcafc2a4...
# 12679  {'offer_id': '9b98b8c7a33c4b65b9aebfe6a799e6d9...
# 12692  {'offer_id': 'ae264e3637204a6fb9bb56bc8210ddfd...
# 12697  {'offer_id': '4d5c57ea9a6940dd891ad53e9dbe8da0...

# %%
offer_completed_df = transcript[transcript.event == 'offer completed']
offer_completed_df.shape
# Out:
# (33579, 4)

# %%
offer_completed_df['offer_completed_id'] = offer_completed_df['value'].apply(lambda x: x['offer_id'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
offer_completed_df['offer_completed_reward'] = offer_completed_df['value'].apply(lambda x: x['reward'])
# Out:
# /opt/conda/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
offer_completed_df = offer_completed_df.drop('value', axis = 1)

# %%
# offer_completed_df.to_csv('offer_completed.csv', index = False)

# %%
offer_completed_df.head()
# Out:
#                  event                            person  time  \
# 12658  offer completed  9fa9ae8f57894cc9a3b8a9bbe0fc1b2f     0
# 12672  offer completed  fe97aa22dd3e48c8b143116a8403dd52     0
# 12679  offer completed  629fc02d56414d91bca360decdfa9288     0
# 12692  offer completed  676506bad68e4161b9bbaffeb039626b     0
# 12697  offer completed  8f7dd3b2afe14c078eb4f6e6fe4ba97d     0
#
#                      offer_completed_id  offer_completed_reward
# 12658  2906b810c7d4411798c6938adc9daaa5                       2
# 12672  fafdcd668e3743c1bb461111dcafc2a4                       2
# 12679  9b98b8c7a33c4b65b9aebfe6a799e6d9                       5
# 12692  ae264e3637204a6fb9bb56bc8210ddfd                      10
# 12697  4d5c57ea9a6940dd891ad53e9dbe8da0                      10

# %%
offer_df = pd.merge(
    offer_received_df,
    portfolio_df,
    how="inner",
    left_on="offer_id",
    right_on="id",
    copy = False,
    sort=True,
)

# %%
offer_df = offer_df.drop('id', axis = 1)

# %%
offer_df = offer_df.rename({'event':'received', 'difficulty': 'minimum_amount_required', 'time': 'time_received'}, axis = 1)

# %%
offer_df = offer_df[['person', 'offer_id', 'received', 'offer', 'offer_type', 'time_received', 'minimum_amount_required', 'duration','reward', 'web', 'email', 'social', 'mobile']]

# %%
offer_df = pd.merge(
    offer_df,
    offer_viewed_df,
    how="left",
    left_on=["person", "offer_id"],
    right_on=["person", "offer"],
    copy = False,
    sort=True,
)

# %%
offer_df = offer_df.rename({'event': 'viewed', 'time': 'time_viewed'}, axis = 1)

# %%
offer_df['viewed'].isna().value_counts()
# Out:
# False    79329
# True     15992
# Name: viewed, dtype: int64

# %%
offer_df['received'].isna().value_counts()
# Out:
# False    95321
# Name: received, dtype: int64

# %%
offer_df = pd.merge(
    offer_df,
    offer_completed_df,
    how="left",
    left_on=["person", "offer_id"],
    right_on=["person", "offer_completed_id"],
    copy = False,
    sort=True,
)

# %%
offer_df = offer_df.rename({'event': 'completed', 'time': 'time_completed'}, axis = 1)

# %%
offer_df = pd.merge(
    offer_df,
    transaction_df,
    how="left",
    on="person",
    copy = False,
    sort=True,
)

# %%
offer_df["event"].isna().value_counts()
# Out:
# False    1032922
# True        2364
# Name: event, dtype: int64

# %%
offer_df = offer_df.drop(["offer_id", "offer_y", "offer_completed_id"], axis = 1)

# %%
offer_df = offer_df.rename({"offer_x": "offer_id", "event": "transaction", "time": "transaction_time"}, axis = 1)

# %%
offer_df
# Out:
#                                    person        received  offer_id  \
# 0        0009655768c64bdeb2e877511632db8f  offer received        10
# 1        0009655768c64bdeb2e877511632db8f  offer received        10
# 2        0009655768c64bdeb2e877511632db8f  offer received        10
# 3        0009655768c64bdeb2e877511632db8f  offer received        10
# 4        0009655768c64bdeb2e877511632db8f  offer received        10
# 5        0009655768c64bdeb2e877511632db8f  offer received        10
# 6        0009655768c64bdeb2e877511632db8f  offer received        10
# 7        0009655768c64bdeb2e877511632db8f  offer received        10
# 8        0009655768c64bdeb2e877511632db8f  offer received         3
# 9        0009655768c64bdeb2e877511632db8f  offer received         3
# 10       0009655768c64bdeb2e877511632db8f  offer received         3
# 11       0009655768c64bdeb2e877511632db8f  offer received         3
# 12       0009655768c64bdeb2e877511632db8f  offer received         3
# 13       0009655768c64bdeb2e877511632db8f  offer received         3
# 14       0009655768c64bdeb2e877511632db8f  offer received         3
# 15       0009655768c64bdeb2e877511632db8f  offer received         3
# 16       0009655768c64bdeb2e877511632db8f  offer received         8
# 17       0009655768c64bdeb2e877511632db8f  offer received         8
# 18       0009655768c64bdeb2e877511632db8f  offer received         8
# 19       0009655768c64bdeb2e877511632db8f  offer received         8
# 20       0009655768c64bdeb2e877511632db8f  offer received         8
# 21       0009655768c64bdeb2e877511632db8f  offer received         8
# 22       0009655768c64bdeb2e877511632db8f  offer received         8
# 23       0009655768c64bdeb2e877511632db8f  offer received         8
# 24       0009655768c64bdeb2e877511632db8f  offer received         9
# 25       0009655768c64bdeb2e877511632db8f  offer received         9
# 26       0009655768c64bdeb2e877511632db8f  offer received         9
# 27       0009655768c64bdeb2e877511632db8f  offer received         9
# 28       0009655768c64bdeb2e877511632db8f  offer received         9
# 29       0009655768c64bdeb2e877511632db8f  offer received         9
# ...                                   ...             ...       ...
# 1035256  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035257  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035258  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035259  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035260  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035261  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035262  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035263  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035264  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035265  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035266  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035267  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035268  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035269  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035270  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 1035271  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035272  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035273  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035274  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035275  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035276  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035277  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035278  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035279  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035280  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035281  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035282  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035283  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035284  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 1035285  ffff82501cea40309d5fdd7edcca4a07  offer received         7
#
#             offer_type  time_received  minimum_amount_required  duration  \
# 0             discount            576                       10       168
# 1             discount            576                       10       168
# 2             discount            576                       10       168
# 3             discount            576                       10       168
# 4             discount            576                       10       168
# 5             discount            576                       10       168
# 6             discount            576                       10       168
# 7             discount            576                       10       168
# 8        informational            336                        0        96
# 9        informational            336                        0        96
# 10       informational            336                        0        96
# 11       informational            336                        0        96
# 12       informational            336                        0        96
# 13       informational            336                        0        96
# 14       informational            336                        0        96
# 15       informational            336                        0        96
# 16       informational            168                        0        72
# 17       informational            168                        0        72
# 18       informational            168                        0        72
# 19       informational            168                        0        72
# 20       informational            168                        0        72
# 21       informational            168                        0        72
# 22       informational            168                        0        72
# 23       informational            168                        0        72
# 24                bogo            408                        5       120
# 25                bogo            408                        5       120
# 26                bogo            408                        5       120
# 27                bogo            408                        5       120
# 28                bogo            408                        5       120
# 29                bogo            408                        5       120
# ...                ...            ...                      ...       ...
# 1035256           bogo            504                        5       168
# 1035257           bogo            504                        5       168
# 1035258           bogo            504                        5       168
# 1035259           bogo            504                        5       168
# 1035260           bogo            504                        5       168
# 1035261           bogo            504                        5       168
# 1035262           bogo            504                        5       168
# 1035263           bogo            504                        5       168
# 1035264           bogo            504                        5       168
# 1035265           bogo            504                        5       168
# 1035266           bogo            504                        5       168
# 1035267           bogo            504                        5       168
# 1035268           bogo            504                        5       168
# 1035269           bogo            504                        5       168
# 1035270           bogo            504                        5       168
# 1035271       discount              0                       10       240
# 1035272       discount              0                       10       240
# 1035273       discount              0                       10       240
# 1035274       discount              0                       10       240
# 1035275       discount              0                       10       240
# 1035276       discount              0                       10       240
# 1035277       discount              0                       10       240
# 1035278       discount              0                       10       240
# 1035279       discount              0                       10       240
# 1035280       discount              0                       10       240
# 1035281       discount              0                       10       240
# 1035282       discount              0                       10       240
# 1035283       discount              0                       10       240
# 1035284       discount              0                       10       240
# 1035285       discount              0                       10       240
#
#          reward  web  email  social  mobile        viewed  time_viewed  \
# 0             2    1      1       0       1           NaN          NaN
# 1             2    1      1       0       1           NaN          NaN
# 2             2    1      1       0       1           NaN          NaN
# 3             2    1      1       0       1           NaN          NaN
# 4             2    1      1       0       1           NaN          NaN
# 5             2    1      1       0       1           NaN          NaN
# 6             2    1      1       0       1           NaN          NaN
# 7             2    1      1       0       1           NaN          NaN
# 8             0    1      1       0       1  offer viewed        372.0
# 9             0    1      1       0       1  offer viewed        372.0
# 10            0    1      1       0       1  offer viewed        372.0
# 11            0    1      1       0       1  offer viewed        372.0
# 12            0    1      1       0       1  offer viewed        372.0
# 13            0    1      1       0       1  offer viewed        372.0
# 14            0    1      1       0       1  offer viewed        372.0
# 15            0    1      1       0       1  offer viewed        372.0
# 16            0    0      1       1       1  offer viewed        192.0
# 17            0    0      1       1       1  offer viewed        192.0
# 18            0    0      1       1       1  offer viewed        192.0
# 19            0    0      1       1       1  offer viewed        192.0
# 20            0    0      1       1       1  offer viewed        192.0
# 21            0    0      1       1       1  offer viewed        192.0
# 22            0    0      1       1       1  offer viewed        192.0
# 23            0    0      1       1       1  offer viewed        192.0
# 24            5    1      1       1       1  offer viewed        456.0
# 25            5    1      1       1       1  offer viewed        456.0
# 26            5    1      1       1       1  offer viewed        456.0
# 27            5    1      1       1       1  offer viewed        456.0
# 28            5    1      1       1       1  offer viewed        456.0
# 29            5    1      1       1       1  offer viewed        456.0
# ...         ...  ...    ...     ...     ...           ...          ...
# 1035256       5    1      1       0       1  offer viewed        534.0
# 1035257       5    1      1       0       1  offer viewed        534.0
# 1035258       5    1      1       0       1  offer viewed        534.0
# 1035259       5    1      1       0       1  offer viewed        534.0
# 1035260       5    1      1       0       1  offer viewed        534.0
# 1035261       5    1      1       0       1  offer viewed        534.0
# 1035262       5    1      1       0       1  offer viewed        534.0
# 1035263       5    1      1       0       1  offer viewed        534.0
# 1035264       5    1      1       0       1  offer viewed        534.0
# 1035265       5    1      1       0       1  offer viewed        534.0
# 1035266       5    1      1       0       1  offer viewed        534.0
# 1035267       5    1      1       0       1  offer viewed        534.0
# 1035268       5    1      1       0       1  offer viewed        534.0
# 1035269       5    1      1       0       1  offer viewed        534.0
# 1035270       5    1      1       0       1  offer viewed        534.0
# 1035271       2    1      1       1       1  offer viewed          6.0
# 1035272       2    1      1       1       1  offer viewed          6.0
# 1035273       2    1      1       1       1  offer viewed          6.0
# 1035274       2    1      1       1       1  offer viewed          6.0
# 1035275       2    1      1       1       1  offer viewed          6.0
# 1035276       2    1      1       1       1  offer viewed          6.0
# 1035277       2    1      1       1       1  offer viewed          6.0
# 1035278       2    1      1       1       1  offer viewed          6.0
# 1035279       2    1      1       1       1  offer viewed          6.0
# 1035280       2    1      1       1       1  offer viewed          6.0
# 1035281       2    1      1       1       1  offer viewed          6.0
# 1035282       2    1      1       1       1  offer viewed          6.0
# 1035283       2    1      1       1       1  offer viewed          6.0
# 1035284       2    1      1       1       1  offer viewed          6.0
# 1035285       2    1      1       1       1  offer viewed          6.0
#
#                completed  time_completed  offer_completed_reward  transaction  \
# 0        offer completed           576.0                     2.0  transaction
# 1        offer completed           576.0                     2.0  transaction
# 2        offer completed           576.0                     2.0  transaction
# 3        offer completed           576.0                     2.0  transaction
# 4        offer completed           576.0                     2.0  transaction
# 5        offer completed           576.0                     2.0  transaction
# 6        offer completed           576.0                     2.0  transaction
# 7        offer completed           576.0                     2.0  transaction
# 8                    NaN             NaN                     NaN  transaction
# 9                    NaN             NaN                     NaN  transaction
# 10                   NaN             NaN                     NaN  transaction
# 11                   NaN             NaN                     NaN  transaction
# 12                   NaN             NaN                     NaN  transaction
# 13                   NaN             NaN                     NaN  transaction
# 14                   NaN             NaN                     NaN  transaction
# 15                   NaN             NaN                     NaN  transaction
# 16                   NaN             NaN                     NaN  transaction
# 17                   NaN             NaN                     NaN  transaction
# 18                   NaN             NaN                     NaN  transaction
# 19                   NaN             NaN                     NaN  transaction
# 20                   NaN             NaN                     NaN  transaction
# 21                   NaN             NaN                     NaN  transaction
# 22                   NaN             NaN                     NaN  transaction
# 23                   NaN             NaN                     NaN  transaction
# 24       offer completed           414.0                     5.0  transaction
# 25       offer completed           414.0                     5.0  transaction
# 26       offer completed           414.0                     5.0  transaction
# 27       offer completed           414.0                     5.0  transaction
# 28       offer completed           414.0                     5.0  transaction
# 29       offer completed           414.0                     5.0  transaction
# ...                  ...             ...                     ...          ...
# 1035256  offer completed           504.0                     5.0  transaction
# 1035257  offer completed           504.0                     5.0  transaction
# 1035258  offer completed           504.0                     5.0  transaction
# 1035259  offer completed           504.0                     5.0  transaction
# 1035260  offer completed           504.0                     5.0  transaction
# 1035261  offer completed           504.0                     5.0  transaction
# 1035262  offer completed           504.0                     5.0  transaction
# 1035263  offer completed           504.0                     5.0  transaction
# 1035264  offer completed           504.0                     5.0  transaction
# 1035265  offer completed           504.0                     5.0  transaction
# 1035266  offer completed           504.0                     5.0  transaction
# 1035267  offer completed           504.0                     5.0  transaction
# 1035268  offer completed           504.0                     5.0  transaction
# 1035269  offer completed           504.0                     5.0  transaction
# 1035270  offer completed           504.0                     5.0  transaction
# 1035271  offer completed            60.0                     2.0  transaction
# 1035272  offer completed            60.0                     2.0  transaction
# 1035273  offer completed            60.0                     2.0  transaction
# 1035274  offer completed            60.0                     2.0  transaction
# 1035275  offer completed            60.0                     2.0  transaction
# 1035276  offer completed            60.0                     2.0  transaction
# 1035277  offer completed            60.0                     2.0  transaction
# 1035278  offer completed            60.0                     2.0  transaction
# 1035279  offer completed            60.0                     2.0  transaction
# 1035280  offer completed            60.0                     2.0  transaction
# 1035281  offer completed            60.0                     2.0  transaction
# 1035282  offer completed            60.0                     2.0  transaction
# 1035283  offer completed            60.0                     2.0  transaction
# 1035284  offer completed            60.0                     2.0  transaction
# 1035285  offer completed            60.0                     2.0  transaction
#
#          transaction_time  amount_spent
# 0                   228.0         22.16
# 1                   414.0          8.57
# 2                   528.0         14.11
# 3                   552.0         13.56
# 4                   576.0         10.27
# 5                   660.0         12.36
# 6                   690.0         28.16
# 7                   696.0         18.41
# 8                   228.0         22.16
# 9                   414.0          8.57
# 10                  528.0         14.11
# 11                  552.0         13.56
# 12                  576.0         10.27
# 13                  660.0         12.36
# 14                  690.0         28.16
# 15                  696.0         18.41
# 16                  228.0         22.16
# 17                  414.0          8.57
# 18                  528.0         14.11
# 19                  552.0         13.56
# 20                  576.0         10.27
# 21                  660.0         12.36
# 22                  690.0         28.16
# 23                  696.0         18.41
# 24                  228.0         22.16
# 25                  414.0          8.57
# 26                  528.0         14.11
# 27                  552.0         13.56
# 28                  576.0         10.27
# 29                  660.0         12.36
# ...                   ...           ...
# 1035256              60.0         16.06
# 1035257              78.0          7.18
# 1035258             120.0          9.12
# 1035259             198.0         22.88
# 1035260             204.0         15.23
# 1035261             234.0         18.08
# 1035262             264.0         23.32
# 1035263             312.0         16.86
# 1035264             384.0         15.57
# 1035265             414.0         17.55
# 1035266             498.0         13.17
# 1035267             504.0          7.79
# 1035268             576.0         14.23
# 1035269             606.0         10.12
# 1035270             648.0         18.91
# 1035271              60.0         16.06
# 1035272              78.0          7.18
# 1035273             120.0          9.12
# 1035274             198.0         22.88
# 1035275             204.0         15.23
# 1035276             234.0         18.08
# 1035277             264.0         23.32
# 1035278             312.0         16.86
# 1035279             384.0         15.57
# 1035280             414.0         17.55
# 1035281             498.0         13.17
# 1035282             504.0          7.79
# 1035283             576.0         14.23
# 1035284             606.0         10.12
# 1035285             648.0         18.91
#
# [1035286 rows x 20 columns]

# %%
offer_df = pd.merge(
    offer_df,
    profile_df,
    how="inner",
    left_on="person",
    right_on="id",
    copy = False,
    sort=True,
)

# %%
offer_df
# Out:
#                                   person        received  offer_id  \
# 0       0009655768c64bdeb2e877511632db8f  offer received        10
# 1       0009655768c64bdeb2e877511632db8f  offer received        10
# 2       0009655768c64bdeb2e877511632db8f  offer received        10
# 3       0009655768c64bdeb2e877511632db8f  offer received        10
# 4       0009655768c64bdeb2e877511632db8f  offer received        10
# 5       0009655768c64bdeb2e877511632db8f  offer received        10
# 6       0009655768c64bdeb2e877511632db8f  offer received        10
# 7       0009655768c64bdeb2e877511632db8f  offer received        10
# 8       0009655768c64bdeb2e877511632db8f  offer received         3
# 9       0009655768c64bdeb2e877511632db8f  offer received         3
# 10      0009655768c64bdeb2e877511632db8f  offer received         3
# 11      0009655768c64bdeb2e877511632db8f  offer received         3
# 12      0009655768c64bdeb2e877511632db8f  offer received         3
# 13      0009655768c64bdeb2e877511632db8f  offer received         3
# 14      0009655768c64bdeb2e877511632db8f  offer received         3
# 15      0009655768c64bdeb2e877511632db8f  offer received         3
# 16      0009655768c64bdeb2e877511632db8f  offer received         8
# 17      0009655768c64bdeb2e877511632db8f  offer received         8
# 18      0009655768c64bdeb2e877511632db8f  offer received         8
# 19      0009655768c64bdeb2e877511632db8f  offer received         8
# 20      0009655768c64bdeb2e877511632db8f  offer received         8
# 21      0009655768c64bdeb2e877511632db8f  offer received         8
# 22      0009655768c64bdeb2e877511632db8f  offer received         8
# 23      0009655768c64bdeb2e877511632db8f  offer received         8
# 24      0009655768c64bdeb2e877511632db8f  offer received         9
# 25      0009655768c64bdeb2e877511632db8f  offer received         9
# 26      0009655768c64bdeb2e877511632db8f  offer received         9
# 27      0009655768c64bdeb2e877511632db8f  offer received         9
# 28      0009655768c64bdeb2e877511632db8f  offer received         9
# 29      0009655768c64bdeb2e877511632db8f  offer received         9
# ...                                  ...             ...       ...
# 941113  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941114  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941115  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941116  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941117  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941118  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941119  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941120  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941121  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941122  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941123  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941124  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941125  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941126  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941127  ffff82501cea40309d5fdd7edcca4a07  offer received         4
# 941128  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941129  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941130  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941131  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941132  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941133  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941134  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941135  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941136  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941137  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941138  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941139  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941140  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941141  ffff82501cea40309d5fdd7edcca4a07  offer received         7
# 941142  ffff82501cea40309d5fdd7edcca4a07  offer received         7
#
#            offer_type  time_received  minimum_amount_required  duration  \
# 0            discount            576                       10       168
# 1            discount            576                       10       168
# 2            discount            576                       10       168
# 3            discount            576                       10       168
# 4            discount            576                       10       168
# 5            discount            576                       10       168
# 6            discount            576                       10       168
# 7            discount            576                       10       168
# 8       informational            336                        0        96
# 9       informational            336                        0        96
# 10      informational            336                        0        96
# 11      informational            336                        0        96
# 12      informational            336                        0        96
# 13      informational            336                        0        96
# 14      informational            336                        0        96
# 15      informational            336                        0        96
# 16      informational            168                        0        72
# 17      informational            168                        0        72
# 18      informational            168                        0        72
# 19      informational            168                        0        72
# 20      informational            168                        0        72
# 21      informational            168                        0        72
# 22      informational            168                        0        72
# 23      informational            168                        0        72
# 24               bogo            408                        5       120
# 25               bogo            408                        5       120
# 26               bogo            408                        5       120
# 27               bogo            408                        5       120
# 28               bogo            408                        5       120
# 29               bogo            408                        5       120
# ...               ...            ...                      ...       ...
# 941113           bogo            504                        5       168
# 941114           bogo            504                        5       168
# 941115           bogo            504                        5       168
# 941116           bogo            504                        5       168
# 941117           bogo            504                        5       168
# 941118           bogo            504                        5       168
# 941119           bogo            504                        5       168
# 941120           bogo            504                        5       168
# 941121           bogo            504                        5       168
# 941122           bogo            504                        5       168
# 941123           bogo            504                        5       168
# 941124           bogo            504                        5       168
# 941125           bogo            504                        5       168
# 941126           bogo            504                        5       168
# 941127           bogo            504                        5       168
# 941128       discount              0                       10       240
# 941129       discount              0                       10       240
# 941130       discount              0                       10       240
# 941131       discount              0                       10       240
# 941132       discount              0                       10       240
# 941133       discount              0                       10       240
# 941134       discount              0                       10       240
# 941135       discount              0                       10       240
# 941136       discount              0                       10       240
# 941137       discount              0                       10       240
# 941138       discount              0                       10       240
# 941139       discount              0                       10       240
# 941140       discount              0                       10       240
# 941141       discount              0                       10       240
# 941142       discount              0                       10       240
#
#         reward  web  email         ...           offer_completed_reward  \
# 0            2    1      1         ...                              2.0
# 1            2    1      1         ...                              2.0
# 2            2    1      1         ...                              2.0
# 3            2    1      1         ...                              2.0
# 4            2    1      1         ...                              2.0
# 5            2    1      1         ...                              2.0
# 6            2    1      1         ...                              2.0
# 7            2    1      1         ...                              2.0
# 8            0    1      1         ...                              NaN
# 9            0    1      1         ...                              NaN
# 10           0    1      1         ...                              NaN
# 11           0    1      1         ...                              NaN
# 12           0    1      1         ...                              NaN
# 13           0    1      1         ...                              NaN
# 14           0    1      1         ...                              NaN
# 15           0    1      1         ...                              NaN
# 16           0    0      1         ...                              NaN
# 17           0    0      1         ...                              NaN
# 18           0    0      1         ...                              NaN
# 19           0    0      1         ...                              NaN
# 20           0    0      1         ...                              NaN
# 21           0    0      1         ...                              NaN
# 22           0    0      1         ...                              NaN
# 23           0    0      1         ...                              NaN
# 24           5    1      1         ...                              5.0
# 25           5    1      1         ...                              5.0
# 26           5    1      1         ...                              5.0
# 27           5    1      1         ...                              5.0
# 28           5    1      1         ...                              5.0
# 29           5    1      1         ...                              5.0
# ...        ...  ...    ...         ...                              ...
# 941113       5    1      1         ...                              5.0
# 941114       5    1      1         ...                              5.0
# 941115       5    1      1         ...                              5.0
# 941116       5    1      1         ...                              5.0
# 941117       5    1      1         ...                              5.0
# 941118       5    1      1         ...                              5.0
# 941119       5    1      1         ...                              5.0
# 941120       5    1      1         ...                              5.0
# 941121       5    1      1         ...                              5.0
# 941122       5    1      1         ...                              5.0
# 941123       5    1      1         ...                              5.0
# 941124       5    1      1         ...                              5.0
# 941125       5    1      1         ...                              5.0
# 941126       5    1      1         ...                              5.0
# 941127       5    1      1         ...                              5.0
# 941128       2    1      1         ...                              2.0
# 941129       2    1      1         ...                              2.0
# 941130       2    1      1         ...                              2.0
# 941131       2    1      1         ...                              2.0
# 941132       2    1      1         ...                              2.0
# 941133       2    1      1         ...                              2.0
# 941134       2    1      1         ...                              2.0
# 941135       2    1      1         ...                              2.0
# 941136       2    1      1         ...                              2.0
# 941137       2    1      1         ...                              2.0
# 941138       2    1      1         ...                              2.0
# 941139       2    1      1         ...                              2.0
# 941140       2    1      1         ...                              2.0
# 941141       2    1      1         ...                              2.0
# 941142       2    1      1         ...                              2.0
#
#         transaction transaction_time  amount_spent  \
# 0       transaction            228.0         22.16
# 1       transaction            414.0          8.57
# 2       transaction            528.0         14.11
# 3       transaction            552.0         13.56
# 4       transaction            576.0         10.27
# 5       transaction            660.0         12.36
# 6       transaction            690.0         28.16
# 7       transaction            696.0         18.41
# 8       transaction            228.0         22.16
# 9       transaction            414.0          8.57
# 10      transaction            528.0         14.11
# 11      transaction            552.0         13.56
# 12      transaction            576.0         10.27
# 13      transaction            660.0         12.36
# 14      transaction            690.0         28.16
# 15      transaction            696.0         18.41
# 16      transaction            228.0         22.16
# 17      transaction            414.0          8.57
# 18      transaction            528.0         14.11
# 19      transaction            552.0         13.56
# 20      transaction            576.0         10.27
# 21      transaction            660.0         12.36
# 22      transaction            690.0         28.16
# 23      transaction            696.0         18.41
# 24      transaction            228.0         22.16
# 25      transaction            414.0          8.57
# 26      transaction            528.0         14.11
# 27      transaction            552.0         13.56
# 28      transaction            576.0         10.27
# 29      transaction            660.0         12.36
# ...             ...              ...           ...
# 941113  transaction             60.0         16.06
# 941114  transaction             78.0          7.18
# 941115  transaction            120.0          9.12
# 941116  transaction            198.0         22.88
# 941117  transaction            204.0         15.23
# 941118  transaction            234.0         18.08
# 941119  transaction            264.0         23.32
# 941120  transaction            312.0         16.86
# 941121  transaction            384.0         15.57
# 941122  transaction            414.0         17.55
# 941123  transaction            498.0         13.17
# 941124  transaction            504.0          7.79
# 941125  transaction            576.0         14.23
# 941126  transaction            606.0         10.12
# 941127  transaction            648.0         18.91
# 941128  transaction             60.0         16.06
# 941129  transaction             78.0          7.18
# 941130  transaction            120.0          9.12
# 941131  transaction            198.0         22.88
# 941132  transaction            204.0         15.23
# 941133  transaction            234.0         18.08
# 941134  transaction            264.0         23.32
# 941135  transaction            312.0         16.86
# 941136  transaction            384.0         15.57
# 941137  transaction            414.0         17.55
# 941138  transaction            498.0         13.17
# 941139  transaction            504.0          7.79
# 941140  transaction            576.0         14.23
# 941141  transaction            606.0         10.12
# 941142  transaction            648.0         18.91
#
#                                       id  age  gender   income  \
# 0       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 1       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 2       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 3       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 4       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 5       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 6       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 7       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 8       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 9       0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 10      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 11      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 12      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 13      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 14      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 15      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 16      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 17      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 18      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 19      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 20      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 21      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 22      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 23      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 24      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 25      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 26      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 27      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 28      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# 29      0009655768c64bdeb2e877511632db8f   33       M  72000.0
# ...                                  ...  ...     ...      ...
# 941113  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941114  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941115  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941116  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941117  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941118  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941119  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941120  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941121  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941122  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941123  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941124  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941125  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941126  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941127  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941128  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941129  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941130  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941131  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941132  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941133  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941134  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941135  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941136  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941137  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941138  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941139  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941140  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941141  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
# 941142  ffff82501cea40309d5fdd7edcca4a07   45       F  62000.0
#
#         became_member_on  membership_duration
# 0             2017-04-21                  461
# 1             2017-04-21                  461
# 2             2017-04-21                  461
# 3             2017-04-21                  461
# 4             2017-04-21                  461
# 5             2017-04-21                  461
# 6             2017-04-21                  461
# 7             2017-04-21                  461
# 8             2017-04-21                  461
# 9             2017-04-21                  461
# 10            2017-04-21                  461
# 11            2017-04-21                  461
# 12            2017-04-21                  461
# 13            2017-04-21                  461
# 14            2017-04-21                  461
# 15            2017-04-21                  461
# 16            2017-04-21                  461
# 17            2017-04-21                  461
# 18            2017-04-21                  461
# 19            2017-04-21                  461
# 20            2017-04-21                  461
# 21            2017-04-21                  461
# 22            2017-04-21                  461
# 23            2017-04-21                  461
# 24            2017-04-21                  461
# 25            2017-04-21                  461
# 26            2017-04-21                  461
# 27            2017-04-21                  461
# 28            2017-04-21                  461
# 29            2017-04-21                  461
# ...                  ...                  ...
# 941113        2016-11-25                  608
# 941114        2016-11-25                  608
# 941115        2016-11-25                  608
# 941116        2016-11-25                  608
# 941117        2016-11-25                  608
# 941118        2016-11-25                  608
# 941119        2016-11-25                  608
# 941120        2016-11-25                  608
# 941121        2016-11-25                  608
# 941122        2016-11-25                  608
# 941123        2016-11-25                  608
# 941124        2016-11-25                  608
# 941125        2016-11-25                  608
# 941126        2016-11-25                  608
# 941127        2016-11-25                  608
# 941128        2016-11-25                  608
# 941129        2016-11-25                  608
# 941130        2016-11-25                  608
# 941131        2016-11-25                  608
# 941132        2016-11-25                  608
# 941133        2016-11-25                  608
# 941134        2016-11-25                  608
# 941135        2016-11-25                  608
# 941136        2016-11-25                  608
# 941137        2016-11-25                  608
# 941138        2016-11-25                  608
# 941139        2016-11-25                  608
# 941140        2016-11-25                  608
# 941141        2016-11-25                  608
# 941142        2016-11-25                  608
#
# [941143 rows x 26 columns]

# %%
offer_df = offer_df.drop("id", axis = 1)

# %%
offer_df = offer_df[["person", "age", "gender", "income", "became_member_on", "membership_duration", "offer_id", "offer_type", "minimum_amount_required", "duration", "reward", "web", "email", "social", "mobile", "transaction", "received", "viewed", "completed", "time_received", "time_viewed", "time_completed", "transaction_time", "amount_spent", "offer_completed_reward" ]]

# %%
offer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941143 entries, 0 to 941142
# Data columns (total 25 columns):
# person                     941143 non-null object
# age                        941143 non-null int64
# gender                     941143 non-null object
# income                     941143 non-null float64
# became_member_on           941143 non-null datetime64[ns]
# membership_duration        941143 non-null int64
# offer_id                   941143 non-null int64
# offer_type                 941143 non-null object
# minimum_amount_required    941143 non-null int64
# duration                   941143 non-null int64
# reward                     941143 non-null int64
# web                        941143 non-null int64
# email                      941143 non-null int64
# social                     941143 non-null int64
# mobile                     941143 non-null int64
# transaction                939311 non-null object
# received                   941143 non-null object
# viewed                     821794 non-null object
# completed                  665198 non-null object
# time_received              941143 non-null int64
# time_viewed                821794 non-null float64
# time_completed             665198 non-null float64
# transaction_time           939311 non-null float64
# amount_spent               939311 non-null float64
# offer_completed_reward     665198 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(11), object(7)
# memory usage: 186.7+ MB

# %%
offer_df['transaction'] = offer_df['transaction'].fillna(0).replace(to_replace="transaction", value=1)

# %%
offer_df['received'] = offer_df['received'].fillna(0).replace(to_replace="offer received", value=1)

# %%
offer_df['viewed'] = offer_df['viewed'].fillna(0).replace(to_replace="offer viewed", value=1)

# %%
offer_df['completed'] = offer_df['completed'].fillna(0).replace(to_replace="offer completed", value=1)

# %%
offer_df["offer_completed_reward"] = offer_df["offer_completed_reward"].fillna(0)

# %%
offer_df["amount_spent"] = offer_df["amount_spent"].fillna(0)

# %%
offer_df["transaction_time"] = offer_df["transaction_time"].fillna(0)

# %%
offer_df["time_completed"] = offer_df["time_completed"].fillna(0)

# %%
offer_df["time_viewed"] = offer_df["time_viewed"].fillna(0)

# %%
offer_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 941143 entries, 0 to 941142
# Data columns (total 25 columns):
# person                     941143 non-null object
# age                        941143 non-null int64
# gender                     941143 non-null object
# income                     941143 non-null float64
# became_member_on           941143 non-null datetime64[ns]
# membership_duration        941143 non-null int64
# offer_id                   941143 non-null int64
# offer_type                 941143 non-null object
# minimum_amount_required    941143 non-null int64
# duration                   941143 non-null int64
# reward                     941143 non-null int64
# web                        941143 non-null int64
# email                      941143 non-null int64
# social                     941143 non-null int64
# mobile                     941143 non-null int64
# transaction                941143 non-null int64
# received                   941143 non-null int64
# viewed                     941143 non-null int64
# completed                  941143 non-null int64
# time_received              941143 non-null int64
# time_viewed                941143 non-null float64
# time_completed             941143 non-null float64
# transaction_time           941143 non-null float64
# amount_spent               941143 non-null float64
# offer_completed_reward     941143 non-null float64
# dtypes: datetime64[ns](1), float64(6), int64(15), object(3)
# memory usage: 186.7+ MB

# %%
# offer_df.to_csv('complete_df.csv', index = False)

# %%
offer_df
# Out:
#                                   person  age gender   income  \
# 0       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 1       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 2       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 3       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 4       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 5       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 6       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 7       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 8       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 9       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 10      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 11      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 12      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 13      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 14      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 15      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 16      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 17      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 18      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 19      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 20      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 21      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 22      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 23      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 24      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 25      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 26      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 27      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 28      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 29      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# ...                                  ...  ...    ...      ...
# 941113  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941114  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941115  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941116  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941117  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941118  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941119  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941120  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941121  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941122  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941123  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941124  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941125  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941126  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941127  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941128  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941129  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941130  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941131  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941132  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941133  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941134  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941135  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941136  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941137  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941138  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941139  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941140  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941141  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941142  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
#
#        became_member_on  membership_duration  offer_id     offer_type  \
# 0            2017-04-21                  461        10       discount
# 1            2017-04-21                  461        10       discount
# 2            2017-04-21                  461        10       discount
# 3            2017-04-21                  461        10       discount
# 4            2017-04-21                  461        10       discount
# 5            2017-04-21                  461        10       discount
# 6            2017-04-21                  461        10       discount
# 7            2017-04-21                  461        10       discount
# 8            2017-04-21                  461         3  informational
# 9            2017-04-21                  461         3  informational
# 10           2017-04-21                  461         3  informational
# 11           2017-04-21                  461         3  informational
# 12           2017-04-21                  461         3  informational
# 13           2017-04-21                  461         3  informational
# 14           2017-04-21                  461         3  informational
# 15           2017-04-21                  461         3  informational
# 16           2017-04-21                  461         8  informational
# 17           2017-04-21                  461         8  informational
# 18           2017-04-21                  461         8  informational
# 19           2017-04-21                  461         8  informational
# 20           2017-04-21                  461         8  informational
# 21           2017-04-21                  461         8  informational
# 22           2017-04-21                  461         8  informational
# 23           2017-04-21                  461         8  informational
# 24           2017-04-21                  461         9           bogo
# 25           2017-04-21                  461         9           bogo
# 26           2017-04-21                  461         9           bogo
# 27           2017-04-21                  461         9           bogo
# 28           2017-04-21                  461         9           bogo
# 29           2017-04-21                  461         9           bogo
# ...                 ...                  ...       ...            ...
# 941113       2016-11-25                  608         4           bogo
# 941114       2016-11-25                  608         4           bogo
# 941115       2016-11-25                  608         4           bogo
# 941116       2016-11-25                  608         4           bogo
# 941117       2016-11-25                  608         4           bogo
# 941118       2016-11-25                  608         4           bogo
# 941119       2016-11-25                  608         4           bogo
# 941120       2016-11-25                  608         4           bogo
# 941121       2016-11-25                  608         4           bogo
# 941122       2016-11-25                  608         4           bogo
# 941123       2016-11-25                  608         4           bogo
# 941124       2016-11-25                  608         4           bogo
# 941125       2016-11-25                  608         4           bogo
# 941126       2016-11-25                  608         4           bogo
# 941127       2016-11-25                  608         4           bogo
# 941128       2016-11-25                  608         7       discount
# 941129       2016-11-25                  608         7       discount
# 941130       2016-11-25                  608         7       discount
# 941131       2016-11-25                  608         7       discount
# 941132       2016-11-25                  608         7       discount
# 941133       2016-11-25                  608         7       discount
# 941134       2016-11-25                  608         7       discount
# 941135       2016-11-25                  608         7       discount
# 941136       2016-11-25                  608         7       discount
# 941137       2016-11-25                  608         7       discount
# 941138       2016-11-25                  608         7       discount
# 941139       2016-11-25                  608         7       discount
# 941140       2016-11-25                  608         7       discount
# 941141       2016-11-25                  608         7       discount
# 941142       2016-11-25                  608         7       discount
#
#         minimum_amount_required  duration           ...            \
# 0                            10       168           ...
# 1                            10       168           ...
# 2                            10       168           ...
# 3                            10       168           ...
# 4                            10       168           ...
# 5                            10       168           ...
# 6                            10       168           ...
# 7                            10       168           ...
# 8                             0        96           ...
# 9                             0        96           ...
# 10                            0        96           ...
# 11                            0        96           ...
# 12                            0        96           ...
# 13                            0        96           ...
# 14                            0        96           ...
# 15                            0        96           ...
# 16                            0        72           ...
# 17                            0        72           ...
# 18                            0        72           ...
# 19                            0        72           ...
# 20                            0        72           ...
# 21                            0        72           ...
# 22                            0        72           ...
# 23                            0        72           ...
# 24                            5       120           ...
# 25                            5       120           ...
# 26                            5       120           ...
# 27                            5       120           ...
# 28                            5       120           ...
# 29                            5       120           ...
# ...                         ...       ...           ...
# 941113                        5       168           ...
# 941114                        5       168           ...
# 941115                        5       168           ...
# 941116                        5       168           ...
# 941117                        5       168           ...
# 941118                        5       168           ...
# 941119                        5       168           ...
# 941120                        5       168           ...
# 941121                        5       168           ...
# 941122                        5       168           ...
# 941123                        5       168           ...
# 941124                        5       168           ...
# 941125                        5       168           ...
# 941126                        5       168           ...
# 941127                        5       168           ...
# 941128                       10       240           ...
# 941129                       10       240           ...
# 941130                       10       240           ...
# 941131                       10       240           ...
# 941132                       10       240           ...
# 941133                       10       240           ...
# 941134                       10       240           ...
# 941135                       10       240           ...
# 941136                       10       240           ...
# 941137                       10       240           ...
# 941138                       10       240           ...
# 941139                       10       240           ...
# 941140                       10       240           ...
# 941141                       10       240           ...
# 941142                       10       240           ...
#
#         transaction  received  viewed  completed  time_received  time_viewed  \
# 0                 1         1       0          1            576          0.0
# 1                 1         1       0          1            576          0.0
# 2                 1         1       0          1            576          0.0
# 3                 1         1       0          1            576          0.0
# 4                 1         1       0          1            576          0.0
# 5                 1         1       0          1            576          0.0
# 6                 1         1       0          1            576          0.0
# 7                 1         1       0          1            576          0.0
# 8                 1         1       1          0            336        372.0
# 9                 1         1       1          0            336        372.0
# 10                1         1       1          0            336        372.0
# 11                1         1       1          0            336        372.0
# 12                1         1       1          0            336        372.0
# 13                1         1       1          0            336        372.0
# 14                1         1       1          0            336        372.0
# 15                1         1       1          0            336        372.0
# 16                1         1       1          0            168        192.0
# 17                1         1       1          0            168        192.0
# 18                1         1       1          0            168        192.0
# 19                1         1       1          0            168        192.0
# 20                1         1       1          0            168        192.0
# 21                1         1       1          0            168        192.0
# 22                1         1       1          0            168        192.0
# 23                1         1       1          0            168        192.0
# 24                1         1       1          1            408        456.0
# 25                1         1       1          1            408        456.0
# 26                1         1       1          1            408        456.0
# 27                1         1       1          1            408        456.0
# 28                1         1       1          1            408        456.0
# 29                1         1       1          1            408        456.0
# ...             ...       ...     ...        ...            ...          ...
# 941113            1         1       1          1            504        534.0
# 941114            1         1       1          1            504        534.0
# 941115            1         1       1          1            504        534.0
# 941116            1         1       1          1            504        534.0
# 941117            1         1       1          1            504        534.0
# 941118            1         1       1          1            504        534.0
# 941119            1         1       1          1            504        534.0
# 941120            1         1       1          1            504        534.0
# 941121            1         1       1          1            504        534.0
# 941122            1         1       1          1            504        534.0
# 941123            1         1       1          1            504        534.0
# 941124            1         1       1          1            504        534.0
# 941125            1         1       1          1            504        534.0
# 941126            1         1       1          1            504        534.0
# 941127            1         1       1          1            504        534.0
# 941128            1         1       1          1              0          6.0
# 941129            1         1       1          1              0          6.0
# 941130            1         1       1          1              0          6.0
# 941131            1         1       1          1              0          6.0
# 941132            1         1       1          1              0          6.0
# 941133            1         1       1          1              0          6.0
# 941134            1         1       1          1              0          6.0
# 941135            1         1       1          1              0          6.0
# 941136            1         1       1          1              0          6.0
# 941137            1         1       1          1              0          6.0
# 941138            1         1       1          1              0          6.0
# 941139            1         1       1          1              0          6.0
# 941140            1         1       1          1              0          6.0
# 941141            1         1       1          1              0          6.0
# 941142            1         1       1          1              0          6.0
#
#         time_completed  transaction_time  amount_spent  offer_completed_reward
# 0                576.0             228.0         22.16                     2.0
# 1                576.0             414.0          8.57                     2.0
# 2                576.0             528.0         14.11                     2.0
# 3                576.0             552.0         13.56                     2.0
# 4                576.0             576.0         10.27                     2.0
# 5                576.0             660.0         12.36                     2.0
# 6                576.0             690.0         28.16                     2.0
# 7                576.0             696.0         18.41                     2.0
# 8                  0.0             228.0         22.16                     0.0
# 9                  0.0             414.0          8.57                     0.0
# 10                 0.0             528.0         14.11                     0.0
# 11                 0.0             552.0         13.56                     0.0
# 12                 0.0             576.0         10.27                     0.0
# 13                 0.0             660.0         12.36                     0.0
# 14                 0.0             690.0         28.16                     0.0
# 15                 0.0             696.0         18.41                     0.0
# 16                 0.0             228.0         22.16                     0.0
# 17                 0.0             414.0          8.57                     0.0
# 18                 0.0             528.0         14.11                     0.0
# 19                 0.0             552.0         13.56                     0.0
# 20                 0.0             576.0         10.27                     0.0
# 21                 0.0             660.0         12.36                     0.0
# 22                 0.0             690.0         28.16                     0.0
# 23                 0.0             696.0         18.41                     0.0
# 24               414.0             228.0         22.16                     5.0
# 25               414.0             414.0          8.57                     5.0
# 26               414.0             528.0         14.11                     5.0
# 27               414.0             552.0         13.56                     5.0
# 28               414.0             576.0         10.27                     5.0
# 29               414.0             660.0         12.36                     5.0
# ...                ...               ...           ...                     ...
# 941113           504.0              60.0         16.06                     5.0
# 941114           504.0              78.0          7.18                     5.0
# 941115           504.0             120.0          9.12                     5.0
# 941116           504.0             198.0         22.88                     5.0
# 941117           504.0             204.0         15.23                     5.0
# 941118           504.0             234.0         18.08                     5.0
# 941119           504.0             264.0         23.32                     5.0
# 941120           504.0             312.0         16.86                     5.0
# 941121           504.0             384.0         15.57                     5.0
# 941122           504.0             414.0         17.55                     5.0
# 941123           504.0             498.0         13.17                     5.0
# 941124           504.0             504.0          7.79                     5.0
# 941125           504.0             576.0         14.23                     5.0
# 941126           504.0             606.0         10.12                     5.0
# 941127           504.0             648.0         18.91                     5.0
# 941128            60.0              60.0         16.06                     2.0
# 941129            60.0              78.0          7.18                     2.0
# 941130            60.0             120.0          9.12                     2.0
# 941131            60.0             198.0         22.88                     2.0
# 941132            60.0             204.0         15.23                     2.0
# 941133            60.0             234.0         18.08                     2.0
# 941134            60.0             264.0         23.32                     2.0
# 941135            60.0             312.0         16.86                     2.0
# 941136            60.0             384.0         15.57                     2.0
# 941137            60.0             414.0         17.55                     2.0
# 941138            60.0             498.0         13.17                     2.0
# 941139            60.0             504.0          7.79                     2.0
# 941140            60.0             576.0         14.23                     2.0
# 941141            60.0             606.0         10.12                     2.0
# 941142            60.0             648.0         18.91                     2.0
#
# [941143 rows x 25 columns]

# %%
viewed_and_completed_df = offer_df.copy()

# %%
viewed_and_completed_df = offer_df[offer_df['viewed'] != 0]

# %%
viewed_and_completed_df
# Out:
#                                   person  age gender   income  \
# 8       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 9       0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 10      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 11      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 12      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 13      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 14      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 15      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 16      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 17      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 18      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 19      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 20      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 21      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 22      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 23      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 24      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 25      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 26      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 27      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 28      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 29      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 30      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 31      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 32      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 33      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 34      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 35      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 36      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# 37      0009655768c64bdeb2e877511632db8f   33      M  72000.0
# ...                                  ...  ...    ...      ...
# 941113  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941114  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941115  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941116  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941117  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941118  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941119  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941120  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941121  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941122  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941123  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941124  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941125  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941126  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941127  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941128  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941129  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941130  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941131  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941132  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941133  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941134  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941135  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941136  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941137  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941138  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941139  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941140  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941141  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
# 941142  ffff82501cea40309d5fdd7edcca4a07   45      F  62000.0
#
#        became_member_on  membership_duration  offer_id     offer_type  \
# 8            2017-04-21                  461         3  informational
# 9            2017-04-21                  461         3  informational
# 10           2017-04-21                  461         3  informational
# 11           2017-04-21                  461         3  informational
# 12           2017-04-21                  461         3  informational
# 13           2017-04-21                  461         3  informational
# 14           2017-04-21                  461         3  informational
# 15           2017-04-21                  461         3  informational
# 16           2017-04-21                  461         8  informational
# 17           2017-04-21                  461         8  informational
# 18           2017-04-21                  461         8  informational
# 19           2017-04-21                  461         8  informational
# 20           2017-04-21                  461         8  informational
# 21           2017-04-21                  461         8  informational
# 22           2017-04-21                  461         8  informational
# 23           2017-04-21                  461         8  informational
# 24           2017-04-21                  461         9           bogo
# 25           2017-04-21                  461         9           bogo
# 26           2017-04-21                  461         9           bogo
# 27           2017-04-21                  461         9           bogo
# 28           2017-04-21                  461         9           bogo
# 29           2017-04-21                  461         9           bogo
# 30           2017-04-21                  461         9           bogo
# 31           2017-04-21                  461         9           bogo
# 32           2017-04-21                  461         7       discount
# 33           2017-04-21                  461         7       discount
# 34           2017-04-21                  461         7       discount
# 35           2017-04-21                  461         7       discount
# 36           2017-04-21                  461         7       discount
# 37           2017-04-21                  461         7       discount
# ...                 ...                  ...       ...            ...
# 941113       2016-11-25                  608         4           bogo
# 941114       2016-11-25                  608         4           bogo
# 941115       2016-11-25                  608         4           bogo
# 941116       2016-11-25                  608         4           bogo
# 941117       2016-11-25                  608         4           bogo
# 941118       2016-11-25                  608         4           bogo
# 941119       2016-11-25                  608         4           bogo
# 941120       2016-11-25                  608         4           bogo
# 941121       2016-11-25                  608         4           bogo
# 941122       2016-11-25                  608         4           bogo
# 941123       2016-11-25                  608         4           bogo
# 941124       2016-11-25                  608         4           bogo
# 941125       2016-11-25                  608         4           bogo
# 941126       2016-11-25                  608         4           bogo
# 941127       2016-11-25                  608         4           bogo
# 941128       2016-11-25                  608         7       discount
# 941129       2016-11-25                  608         7       discount
# 941130       2016-11-25                  608         7       discount
# 941131       2016-11-25                  608         7       discount
# 941132       2016-11-25                  608         7       discount
# 941133       2016-11-25                  608         7       discount
# 941134       2016-11-25                  608         7       discount
# 941135       2016-11-25                  608         7       discount
# 941136       2016-11-25                  608         7       discount
# 941137       2016-11-25                  608         7       discount
# 941138       2016-11-25                  608         7       discount
# 941139       2016-11-25                  608         7       discount
# 941140       2016-11-25                  608         7       discount
# 941141       2016-11-25                  608         7       discount
# 941142       2016-11-25                  608         7       discount
#
#         minimum_amount_required  duration           ...            \
# 8                             0        96           ...
# 9                             0        96           ...
# 10                            0        96           ...
# 11                            0        96           ...
# 12                            0        96           ...
# 13                            0        96           ...
# 14                            0        96           ...
# 15                            0        96           ...
# 16                            0        72           ...
# 17                            0        72           ...
# 18                            0        72           ...
# 19                            0        72           ...
# 20                            0        72           ...
# 21                            0        72           ...
# 22                            0        72           ...
# 23                            0        72           ...
# 24                            5       120           ...
# 25                            5       120           ...
# 26                            5       120           ...
# 27                            5       120           ...
# 28                            5       120           ...
# 29                            5       120           ...
# 30                            5       120           ...
# 31                            5       120           ...
# 32                           10       240           ...
# 33                           10       240           ...
# 34                           10       240           ...
# 35                           10       240           ...
# 36                           10       240           ...
# 37                           10       240           ...
# ...                         ...       ...           ...
# 941113                        5       168           ...
# 941114                        5       168           ...
# 941115                        5       168           ...
# 941116                        5       168           ...
# 941117                        5       168           ...
# 941118                        5       168           ...
# 941119                        5       168           ...
# 941120                        5       168           ...
# 941121                        5       168           ...
# 941122                        5       168           ...
# 941123                        5       168           ...
# 941124                        5       168           ...
# 941125                        5       168           ...
# 941126                        5       168           ...
# 941127                        5       168           ...
# 941128                       10       240           ...
# 941129                       10       240           ...
# 941130                       10       240           ...
# 941131                       10       240           ...
# 941132                       10       240           ...
# 941133                       10       240           ...
# 941134                       10       240           ...
# 941135                       10       240           ...
# 941136                       10       240           ...
# 941137                       10       240           ...
# 941138                       10       240           ...
# 941139                       10       240           ...
# 941140                       10       240           ...
# 941141                       10       240           ...
# 941142                       10       240           ...
#
#         transaction  received  viewed  completed  time_received  time_viewed  \
# 8                 1         1       1          0            336        372.0
# 9                 1         1       1          0            336        372.0
# 10                1         1       1          0            336        372.0
# 11                1         1       1          0            336        372.0
# 12                1         1       1          0            336        372.0
# 13                1         1       1          0            336        372.0
# 14                1         1       1          0            336        372.0
# 15                1         1       1          0            336        372.0
# 16                1         1       1          0            168        192.0
# 17                1         1       1          0            168        192.0
# 18                1         1       1          0            168        192.0
# 19                1         1       1          0            168        192.0
# 20                1         1       1          0            168        192.0
# 21                1         1       1          0            168        192.0
# 22                1         1       1          0            168        192.0
# 23                1         1       1          0            168        192.0
# 24                1         1       1          1            408        456.0
# 25                1         1       1          1            408        456.0
# 26                1         1       1          1            408        456.0
# 27                1         1       1          1            408        456.0
# 28                1         1       1          1            408        456.0
# 29                1         1       1          1            408        456.0
# 30                1         1       1          1            408        456.0
# 31                1         1       1          1            408        456.0
# 32                1         1       1          1            504        540.0
# 33                1         1       1          1            504        540.0
# 34                1         1       1          1            504        540.0
# 35                1         1       1          1            504        540.0
# 36                1         1       1          1            504        540.0
# 37                1         1       1          1            504        540.0
# ...             ...       ...     ...        ...            ...          ...
# 941113            1         1       1          1            504        534.0
# 941114            1         1       1          1            504        534.0
# 941115            1         1       1          1            504        534.0
# 941116            1         1       1          1            504        534.0
# 941117            1         1       1          1            504        534.0
# 941118            1         1       1          1            504        534.0
# 941119            1         1       1          1            504        534.0
# 941120            1         1       1          1            504        534.0
# 941121            1         1       1          1            504        534.0
# 941122            1         1       1          1            504        534.0
# 941123            1         1       1          1            504        534.0
# 941124            1         1       1          1            504        534.0
# 941125            1         1       1          1            504        534.0
# 941126            1         1       1          1            504        534.0
# 941127            1         1       1          1            504        534.0
# 941128            1         1       1          1              0          6.0
# 941129            1         1       1          1              0          6.0
# 941130            1         1       1          1              0          6.0
# 941131            1         1       1          1              0          6.0
# 941132            1         1       1          1              0          6.0
# 941133            1         1       1          1              0          6.0
# 941134            1         1       1          1              0          6.0
# 941135            1         1       1          1              0          6.0
# 941136            1         1       1          1              0          6.0
# 941137            1         1       1          1              0          6.0
# 941138            1         1       1          1              0          6.0
# 941139            1         1       1          1              0          6.0
# 941140            1         1       1          1              0          6.0
# 941141            1         1       1          1              0          6.0
# 941142            1         1       1          1              0          6.0
#
#         time_completed  transaction_time  amount_spent  offer_completed_reward
# 8                  0.0             228.0         22.16                     0.0
# 9                  0.0             414.0          8.57                     0.0
# 10                 0.0             528.0         14.11                     0.0
# 11                 0.0             552.0         13.56                     0.0
# 12                 0.0             576.0         10.27                     0.0
# 13                 0.0             660.0         12.36                     0.0
# 14                 0.0             690.0         28.16                     0.0
# 15                 0.0             696.0         18.41                     0.0
# 16                 0.0             228.0         22.16                     0.0
# 17                 0.0             414.0          8.57                     0.0
# 18                 0.0             528.0         14.11                     0.0
# 19                 0.0             552.0         13.56                     0.0
# 20                 0.0             576.0         10.27                     0.0
# 21                 0.0             660.0         12.36                     0.0
# 22                 0.0             690.0         28.16                     0.0
# 23                 0.0             696.0         18.41                     0.0
# 24               414.0             228.0         22.16                     5.0
# 25               414.0             414.0          8.57                     5.0
# 26               414.0             528.0         14.11                     5.0
# 27               414.0             552.0         13.56                     5.0
# 28               414.0             576.0         10.27                     5.0
# 29               414.0             660.0         12.36                     5.0
# 30               414.0             690.0         28.16                     5.0
# 31               414.0             696.0         18.41                     5.0
# 32               528.0             228.0         22.16                     2.0
# 33               528.0             414.0          8.57                     2.0
# 34               528.0             528.0         14.11                     2.0
# 35               528.0             552.0         13.56                     2.0
# 36               528.0             576.0         10.27                     2.0
# 37               528.0             660.0         12.36                     2.0
# ...                ...               ...           ...                     ...
# 941113           504.0              60.0         16.06                     5.0
# 941114           504.0              78.0          7.18                     5.0
# 941115           504.0             120.0          9.12                     5.0
# 941116           504.0             198.0         22.88                     5.0
# 941117           504.0             204.0         15.23                     5.0
# 941118           504.0             234.0         18.08                     5.0
# 941119           504.0             264.0         23.32                     5.0
# 941120           504.0             312.0         16.86                     5.0
# 941121           504.0             384.0         15.57                     5.0
# 941122           504.0             414.0         17.55                     5.0
# 941123           504.0             498.0         13.17                     5.0
# 941124           504.0             504.0          7.79                     5.0
# 941125           504.0             576.0         14.23                     5.0
# 941126           504.0             606.0         10.12                     5.0
# 941127           504.0             648.0         18.91                     5.0
# 941128            60.0              60.0         16.06                     2.0
# 941129            60.0              78.0          7.18                     2.0
# 941130            60.0             120.0          9.12                     2.0
# 941131            60.0             198.0         22.88                     2.0
# 941132            60.0             204.0         15.23                     2.0
# 941133            60.0             234.0         18.08                     2.0
# 941134            60.0             264.0         23.32                     2.0
# 941135            60.0             312.0         16.86                     2.0
# 941136            60.0             384.0         15.57                     2.0
# 941137            60.0             414.0         17.55                     2.0
# 941138            60.0             498.0         13.17                     2.0
# 941139            60.0             504.0          7.79                     2.0
# 941140            60.0             576.0         14.23                     2.0
# 941141            60.0             606.0         10.12                     2.0
# 941142            60.0             648.0         18.91                     2.0
#
# [821794 rows x 25 columns]

# %%
# viewed_and_completed_df.to_csv('viewed_completed.csv', index = False)
